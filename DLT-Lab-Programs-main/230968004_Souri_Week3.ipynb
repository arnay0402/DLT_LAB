# %% [markdown]
# ## Name: Souri Rishik Volety
# ## Reg No: 230968004

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import fashion_mnist, cifar10
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Dropout, BatchNormalization, Activation
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import regularizers

tf.random.set_seed(42)

# %% [markdown]
# ## Question 1 - FASHION MNIST DataSet

# %%
(x_train_fmnist, y_train_fmnist), (x_test_fmnist, y_test_fmnist) = fashion_mnist.load_data()

# %%
num_classes_fmnist = len(np.unique(y_train_fmnist))
print(f"Number of classes in Fashion MNIST: {num_classes_fmnist}")
# Out:
# Number of classes in Fashion MNIST: 10

# %%
print(f"Image shape: {x_train_fmnist[0].shape}")
# Out:
# Image shape: (28, 28)

# %%
class_names_fmnist = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
                      'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

plt.figure(figsize=(10,5))
for i in range(num_classes_fmnist):
    idx = np.where(y_train_fmnist == i)[0][0]
    plt.subplot(2, 5, i+1)
    plt.imshow(x_train_fmnist[idx], cmap='gray')
    plt.title(class_names_fmnist[i])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
x_train_fmnist = x_train_fmnist / 255.0
x_test_fmnist = x_test_fmnist / 255.0

x_train_fmnist_cnn = x_train_fmnist.reshape(-1, 28, 28, 1)
x_test_fmnist_cnn = x_test_fmnist.reshape(-1, 28, 28, 1)

y_train_fmnist_cat = to_categorical(y_train_fmnist)
y_test_fmnist_cat = to_categorical(y_test_fmnist)

# %%
fcnn_fmnist = Sequential([
    Flatten(input_shape=(28, 28)),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),

    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),

    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.2),

    Dense(num_classes_fmnist, activation='softmax')
])

fcnn_fmnist.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history_fcnn_fmnist = fcnn_fmnist.fit(
    x_train_fmnist, y_train_fmnist_cat,
    epochs=50,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stop]
)
# Out:
# C:\Users\SOURI\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.7473 - loss: 0.7222 - val_accuracy: 0.8414 - val_loss: 0.4304
# Epoch 2/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step - accuracy: 0.8340 - loss: 0.4595 - val_accuracy: 0.8508 - val_loss: 0.3972
# Epoch 3/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8458 - loss: 0.4273 - val_accuracy: 0.8395 - val_loss: 0.4230
# Epoch 4/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8531 - loss: 0.4082 - val_accuracy: 0.8593 - val_loss: 0.3750
# Epoch 5/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8605 - loss: 0.3895 - val_accuracy: 0.8643 - val_loss: 0.3658
# Epoch 6/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8600 - loss: 0.3852 - val_accuracy: 0.8707 - val_loss: 0.3490
# Epoch 7/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8647 - loss: 0.3722 - val_accuracy: 0.8636 - val_loss: 0.3588
# Epoch 8/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 9ms/step - accuracy: 0.8711 - loss: 0.3531 - val_accuracy: 0.8687 - val_loss: 0.3484
# Epoch 9/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8722 - loss: 0.3460 - val_accuracy: 0.8694 - val_loss: 0.3464
# Epoch 10/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8746 - loss: 0.3418 - val_accuracy: 0.8621 - val_loss: 0.3821
# Epoch 11/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8749 - loss: 0.3390 - val_accuracy: 0.8789 - val_loss: 0.3205
# Epoch 12/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8821 - loss: 0.3236 - val_accuracy: 0.8694 - val_loss: 0.3448
# Epoch 13/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8813 - loss: 0.3244 - val_accuracy: 0.8784 - val_loss: 0.3315
# Epoch 14/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8856 - loss: 0.3161 - val_accuracy: 0.8801 - val_loss: 0.3229
# Epoch 15/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8863 - loss: 0.3126 - val_accuracy: 0.8821 - val_loss: 0.3231
# Epoch 16/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8855 - loss: 0.3088 - val_accuracy: 0.8830 - val_loss: 0.3223
# Epoch 17/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8859 - loss: 0.3085 - val_accuracy: 0.8791 - val_loss: 0.3202
# Epoch 18/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8891 - loss: 0.3042 - val_accuracy: 0.8842 - val_loss: 0.3139
# Epoch 19/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8886 - loss: 0.3006 - val_accuracy: 0.8842 - val_loss: 0.3173
# Epoch 20/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8905 - loss: 0.2961 - val_accuracy: 0.8850 - val_loss: 0.3088
# Epoch 21/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8941 - loss: 0.2874 - val_accuracy: 0.8827 - val_loss: 0.3172
# Epoch 22/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8959 - loss: 0.2838 - val_accuracy: 0.8840 - val_loss: 0.3106
# Epoch 23/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8944 - loss: 0.2825 - val_accuracy: 0.8823 - val_loss: 0.3224
# Epoch 24/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - accuracy: 0.8959 - loss: 0.2770 - val_accuracy: 0.8852 - val_loss: 0.3137
# Epoch 25/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8967 - loss: 0.2775 - val_accuracy: 0.8841 - val_loss: 0.3151
# Epoch 26/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.8989 - loss: 0.2693 - val_accuracy: 0.8917 - val_loss: 0.3039
# Epoch 27/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9009 - loss: 0.2678 - val_accuracy: 0.8845 - val_loss: 0.3188
# Epoch 28/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9006 - loss: 0.2656 - val_accuracy: 0.8839 - val_loss: 0.3164
# Epoch 29/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9043 - loss: 0.2634 - val_accuracy: 0.8812 - val_loss: 0.3197
# Epoch 30/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9030 - loss: 0.2590 - val_accuracy: 0.8884 - val_loss: 0.3123
# Epoch 31/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9029 - loss: 0.2592 - val_accuracy: 0.8859 - val_loss: 0.3159
# Epoch 32/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9055 - loss: 0.2555 - val_accuracy: 0.8852 - val_loss: 0.3238
# Epoch 33/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9044 - loss: 0.2556 - val_accuracy: 0.8873 - val_loss: 0.3139
# Epoch 34/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9056 - loss: 0.2528 - val_accuracy: 0.8871 - val_loss: 0.3099
# Epoch 35/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9078 - loss: 0.2462 - val_accuracy: 0.8827 - val_loss: 0.3165
# Epoch 36/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9093 - loss: 0.2434 - val_accuracy: 0.8859 - val_loss: 0.3095

# %%
test_loss, test_acc = fcnn_fmnist.evaluate(x_test_fmnist, y_test_fmnist_cat, verbose=0)
print(f"FCNN test Accuracy for Fashion MNIST: {test_acc:.4f}")
# Out:
# FCNN test Accuracy for Fashion MNIST: 0.8804

# %%
plt.plot(history_fcnn_fmnist.history['accuracy'], label='Train Accuracy')
plt.plot(history_fcnn_fmnist.history['val_accuracy'], label='Validation Accuracy')
plt.title('FCNN - Fashion MNIST')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
cnn1_fmnist = Sequential([
    Conv2D(32, (5, 5), strides=1, padding='valid', input_shape=(28, 28, 1)),
    tf.keras.layers.ReLU(),
    MaxPooling2D(pool_size=(2, 2), strides=2),
    Dropout(0.3),
    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.3),
    Dense(num_classes_fmnist, activation='softmax')
])
cnn1_fmnist.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=5,
    restore_best_weights=True
)
history_cnn1_fmnist = cnn1_fmnist.fit(
    x_train_fmnist_cnn, y_train_fmnist_cat,
    epochs=50,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.7383 - loss: 0.7269 - val_accuracy: 0.8703 - val_loss: 0.3677
# Epoch 2/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 13ms/step - accuracy: 0.8633 - loss: 0.3838 - val_accuracy: 0.8839 - val_loss: 0.3192
# Epoch 3/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.8773 - loss: 0.3397 - val_accuracy: 0.8915 - val_loss: 0.3029
# Epoch 4/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.8877 - loss: 0.3107 - val_accuracy: 0.8956 - val_loss: 0.2835
# Epoch 5/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.8925 - loss: 0.2950 - val_accuracy: 0.8963 - val_loss: 0.2751
# Epoch 6/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.8992 - loss: 0.2772 - val_accuracy: 0.9014 - val_loss: 0.2733
# Epoch 7/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9045 - loss: 0.2583 - val_accuracy: 0.9009 - val_loss: 0.2662
# Epoch 8/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9090 - loss: 0.2456 - val_accuracy: 0.9019 - val_loss: 0.2653
# Epoch 9/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9117 - loss: 0.2366 - val_accuracy: 0.9061 - val_loss: 0.2558
# Epoch 10/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9159 - loss: 0.2246 - val_accuracy: 0.9091 - val_loss: 0.2522
# Epoch 11/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9198 - loss: 0.2161 - val_accuracy: 0.9062 - val_loss: 0.2563
# Epoch 12/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9224 - loss: 0.2048 - val_accuracy: 0.9071 - val_loss: 0.2556
# Epoch 13/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9256 - loss: 0.1954 - val_accuracy: 0.9107 - val_loss: 0.2579
# Epoch 14/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9264 - loss: 0.1944 - val_accuracy: 0.9107 - val_loss: 0.2619
# Epoch 15/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9275 - loss: 0.1896 - val_accuracy: 0.9127 - val_loss: 0.2524

# %%
test_loss, test_acc = cnn1_fmnist.evaluate(x_test_fmnist_cnn, y_test_fmnist_cat, verbose=0)
print(f"CNN1 test Accuracy for Fashion MNIST: {test_acc:.4f}")
# Out:
# CNN1 test Accuracy for Fashion MNIST: 0.9014

# %%
plt.plot(history_cnn1_fmnist.history['accuracy'], label='Train Accuracy')
plt.plot(history_cnn1_fmnist.history['val_accuracy'], label='Validation Accuracy')
plt.title('CNN1 - Fashion MNIST')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
cnn2_fmnist = Sequential([
    Conv2D(32, (3, 3), strides=1, padding='valid', input_shape=(28, 28, 1)),
    BatchNormalization(),
    tf.keras.layers.ReLU(),

    Conv2D(32, (3, 3), strides=1, padding='valid'),
    BatchNormalization(),
    tf.keras.layers.ReLU(),

    MaxPooling2D(pool_size=(2, 2), strides=2),
    Dropout(0.2),

    Flatten(),
    Dense(100, activation='relu'),
    Dropout(0.3),
    Dense(num_classes_fmnist, activation='softmax')
])

cnn2_fmnist.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(
    monitor='val_loss',
    patience=7,
    restore_best_weights=True
)

history_cnn2_fmnist = cnn2_fmnist.fit(
    x_train_fmnist_cnn, y_train_fmnist_cat,
    epochs=50,
    batch_size=64,
    validation_split=0.2,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.7491 - loss: 0.7253 - val_accuracy: 0.8708 - val_loss: 0.3548
# Epoch 2/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 33s 44ms/step - accuracy: 0.8622 - loss: 0.3849 - val_accuracy: 0.8946 - val_loss: 0.2902
# Epoch 3/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 34s 46ms/step - accuracy: 0.8813 - loss: 0.3250 - val_accuracy: 0.9007 - val_loss: 0.2663
# Epoch 4/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 34s 45ms/step - accuracy: 0.8925 - loss: 0.2934 - val_accuracy: 0.9109 - val_loss: 0.2455
# Epoch 5/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 34s 45ms/step - accuracy: 0.9031 - loss: 0.2631 - val_accuracy: 0.9087 - val_loss: 0.2498
# Epoch 6/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 34s 45ms/step - accuracy: 0.9081 - loss: 0.2460 - val_accuracy: 0.9146 - val_loss: 0.2371
# Epoch 7/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 34s 45ms/step - accuracy: 0.9151 - loss: 0.2271 - val_accuracy: 0.9120 - val_loss: 0.2388
# Epoch 8/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 34s 45ms/step - accuracy: 0.9193 - loss: 0.2175 - val_accuracy: 0.9127 - val_loss: 0.2462
# Epoch 9/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 34s 45ms/step - accuracy: 0.9257 - loss: 0.2017 - val_accuracy: 0.9107 - val_loss: 0.2543
# Epoch 10/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 35s 47ms/step - accuracy: 0.9288 - loss: 0.1900 - val_accuracy: 0.9199 - val_loss: 0.2307
# Epoch 11/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 34s 45ms/step - accuracy: 0.9321 - loss: 0.1786 - val_accuracy: 0.9168 - val_loss: 0.2368
# Epoch 12/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 34s 45ms/step - accuracy: 0.9357 - loss: 0.1712 - val_accuracy: 0.9222 - val_loss: 0.2313
# Epoch 13/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 34s 46ms/step - accuracy: 0.9394 - loss: 0.1607 - val_accuracy: 0.9159 - val_loss: 0.2457
# Epoch 14/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 34s 45ms/step - accuracy: 0.9406 - loss: 0.1560 - val_accuracy: 0.9194 - val_loss: 0.2451
# Epoch 15/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 34s 45ms/step - accuracy: 0.9432 - loss: 0.1509 - val_accuracy: 0.9140 - val_loss: 0.2552
# Epoch 16/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 34s 46ms/step - accuracy: 0.9450 - loss: 0.1440 - val_accuracy: 0.9227 - val_loss: 0.2404
# Epoch 17/50
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 34s 46ms/step - accuracy: 0.9473 - loss: 0.1366 - val_accuracy: 0.9225 - val_loss: 0.2384

# %%
test_loss, test_acc = cnn2_fmnist.evaluate(x_test_fmnist_cnn, y_test_fmnist_cat, verbose=0)
print(f"CNN2 test Accuracy for Fashion MNIST: {test_acc:.4f}")
# Out:
# CNN2 test Accuracy for Fashion MNIST: 0.9137

# %%
plt.plot(history_cnn2_fmnist.history['accuracy'], label='Train Accuracy')
plt.plot(history_cnn2_fmnist.history['val_accuracy'], label='Validation Accuracy')
plt.title('CNN1 - Fashion MNIST')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(history_fcnn_fmnist.history['val_accuracy'], label='FCNN Val Accuracy')
plt.plot(history_cnn1_fmnist.history['val_accuracy'], label='CNN-1 Val Accuracy')
plt.plot(history_cnn2_fmnist.history['val_accuracy'], label='CNN-2 Val Accuracy')
plt.title('Validation Accuracy Comparison (Fashion MNIST)')
plt.xlabel('Epochs')
plt.ylabel('Validation Accuracy')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Question 2 - CIFAR-10 DataSet

# %%
(x_train_cifar, y_train_cifar), (x_test_cifar, y_test_cifar) = cifar10.load_data()

# %%
print(f"Number of classes in CIFAR-10: {len(np.unique(y_train_cifar))}")
# Out:
# Number of classes in CIFAR-10: 10

# %%
print(f"Image shape: {x_train_cifar[0].shape}")
# Out:
# Image shape: (32, 32, 3)

# %%
class_names_cifar = ['Airplane', 'Automobile', 'Bird', 'Cat', 'Deer',
                     'Dog', 'Frog', 'Horse', 'Ship', 'Truck']

plt.figure(figsize=(10,5))
for i in range(10):
    idx = np.where(y_train_cifar == i)[0][0]
    plt.subplot(2, 5, i+1)
    plt.imshow(x_train_cifar[idx])
    plt.title(class_names_cifar[i])
    plt.axis('off')
plt.tight_layout()
plt.show()

# %%
x_train_cifar = x_train_cifar / 255.0
x_test_cifar = x_test_cifar / 255.0

y_train_cifar_cat = to_categorical(y_train_cifar)
y_test_cifar_cat = to_categorical(y_test_cifar)

# %%
fcnn_cifar10 = Sequential([
    Flatten(input_shape=(32, 32, 3)),
    Dense(1024, activation='relu'),
    BatchNormalization(),
    Dropout(0.4),
    
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dropout(0.4),
    
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.3),
    
    Dense(10, activation='softmax')
])

optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)

fcnn_cifar10.compile(
    optimizer=optimizer,
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-5)

history_fcnn_cifar = fcnn_cifar10.fit(
    x_train_cifar, y_train_cifar_cat,
    epochs=50,
    batch_size=128,
    validation_split=0.2,
    callbacks=[early_stop, reduce_lr]
)
# Out:
# C:\Users\SOURI\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 13s 35ms/step - accuracy: 0.2642 - loss: 2.2380 - val_accuracy: 0.3769 - val_loss: 1.7337 - learning_rate: 0.0100
# Epoch 2/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 34ms/step - accuracy: 0.3705 - loss: 1.7516 - val_accuracy: 0.3672 - val_loss: 1.7660 - learning_rate: 0.0100
# Epoch 3/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.3954 - loss: 1.6925 - val_accuracy: 0.3958 - val_loss: 1.7090 - learning_rate: 0.0100
# Epoch 4/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - accuracy: 0.4081 - loss: 1.6504 - val_accuracy: 0.4197 - val_loss: 1.6315 - learning_rate: 0.0100
# Epoch 5/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 37ms/step - accuracy: 0.4131 - loss: 1.6334 - val_accuracy: 0.4113 - val_loss: 1.6593 - learning_rate: 0.0100
# Epoch 6/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.4218 - loss: 1.6149 - val_accuracy: 0.4224 - val_loss: 1.6392 - learning_rate: 0.0100
# Epoch 7/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.4192 - loss: 1.6157 - val_accuracy: 0.4338 - val_loss: 1.5905 - learning_rate: 0.0100
# Epoch 8/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.4249 - loss: 1.6034 - val_accuracy: 0.4289 - val_loss: 1.5951 - learning_rate: 0.0100
# Epoch 9/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4269 - loss: 1.5985 - val_accuracy: 0.4172 - val_loss: 1.6214 - learning_rate: 0.0100
# Epoch 10/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.4293 - loss: 1.5920 - val_accuracy: 0.4128 - val_loss: 1.6664 - learning_rate: 0.0100
# Epoch 11/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 36ms/step - accuracy: 0.4340 - loss: 1.5764 - val_accuracy: 0.4586 - val_loss: 1.5264 - learning_rate: 0.0050
# Epoch 12/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.4454 - loss: 1.5490 - val_accuracy: 0.4699 - val_loss: 1.4914 - learning_rate: 0.0050
# Epoch 13/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.4460 - loss: 1.5395 - val_accuracy: 0.4691 - val_loss: 1.5101 - learning_rate: 0.0050
# Epoch 14/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4498 - loss: 1.5292 - val_accuracy: 0.4772 - val_loss: 1.4685 - learning_rate: 0.0050
# Epoch 15/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4521 - loss: 1.5180 - val_accuracy: 0.4413 - val_loss: 1.5677 - learning_rate: 0.0050
# Epoch 16/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4521 - loss: 1.5175 - val_accuracy: 0.4770 - val_loss: 1.4690 - learning_rate: 0.0050
# Epoch 17/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4636 - loss: 1.4963 - val_accuracy: 0.4525 - val_loss: 1.5311 - learning_rate: 0.0050
# Epoch 18/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4713 - loss: 1.4809 - val_accuracy: 0.4897 - val_loss: 1.4320 - learning_rate: 0.0025
# Epoch 19/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4757 - loss: 1.4637 - val_accuracy: 0.4857 - val_loss: 1.4380 - learning_rate: 0.0025
# Epoch 20/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4767 - loss: 1.4584 - val_accuracy: 0.4982 - val_loss: 1.4134 - learning_rate: 0.0025
# Epoch 21/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4793 - loss: 1.4550 - val_accuracy: 0.4894 - val_loss: 1.4315 - learning_rate: 0.0025
# Epoch 22/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - accuracy: 0.4801 - loss: 1.4490 - val_accuracy: 0.4976 - val_loss: 1.4124 - learning_rate: 0.0025
# Epoch 23/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4854 - loss: 1.4434 - val_accuracy: 0.4954 - val_loss: 1.4131 - learning_rate: 0.0025
# Epoch 24/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4854 - loss: 1.4355 - val_accuracy: 0.4957 - val_loss: 1.4136 - learning_rate: 0.0025
# Epoch 25/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4855 - loss: 1.4368 - val_accuracy: 0.4963 - val_loss: 1.4090 - learning_rate: 0.0025
# Epoch 26/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4846 - loss: 1.4320 - val_accuracy: 0.4995 - val_loss: 1.4015 - learning_rate: 0.0025
# Epoch 27/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4884 - loss: 1.4314 - val_accuracy: 0.5000 - val_loss: 1.4078 - learning_rate: 0.0025
# Epoch 28/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4878 - loss: 1.4276 - val_accuracy: 0.5033 - val_loss: 1.4002 - learning_rate: 0.0025
# Epoch 29/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4898 - loss: 1.4282 - val_accuracy: 0.5025 - val_loss: 1.4013 - learning_rate: 0.0025
# Epoch 30/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4904 - loss: 1.4263 - val_accuracy: 0.5001 - val_loss: 1.4122 - learning_rate: 0.0025
# Epoch 31/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4930 - loss: 1.4129 - val_accuracy: 0.4983 - val_loss: 1.4064 - learning_rate: 0.0025
# Epoch 32/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.4911 - loss: 1.4090 - val_accuracy: 0.5054 - val_loss: 1.3942 - learning_rate: 0.0012
# Epoch 33/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5046 - loss: 1.3895 - val_accuracy: 0.5130 - val_loss: 1.3758 - learning_rate: 0.0012
# Epoch 34/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5032 - loss: 1.3910 - val_accuracy: 0.5134 - val_loss: 1.3661 - learning_rate: 0.0012
# Epoch 35/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5006 - loss: 1.3818 - val_accuracy: 0.5169 - val_loss: 1.3663 - learning_rate: 0.0012
# Epoch 36/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5020 - loss: 1.3808 - val_accuracy: 0.5099 - val_loss: 1.3808 - learning_rate: 0.0012
# Epoch 37/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5073 - loss: 1.3768 - val_accuracy: 0.5129 - val_loss: 1.3778 - learning_rate: 0.0012
# Epoch 38/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5129 - loss: 1.3627 - val_accuracy: 0.5184 - val_loss: 1.3602 - learning_rate: 6.2500e-04
# Epoch 39/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5104 - loss: 1.3601 - val_accuracy: 0.5189 - val_loss: 1.3552 - learning_rate: 6.2500e-04
# Epoch 40/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5135 - loss: 1.3630 - val_accuracy: 0.5175 - val_loss: 1.3631 - learning_rate: 6.2500e-04
# Epoch 41/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5139 - loss: 1.3561 - val_accuracy: 0.5231 - val_loss: 1.3529 - learning_rate: 6.2500e-04
# Epoch 42/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5127 - loss: 1.3594 - val_accuracy: 0.5196 - val_loss: 1.3554 - learning_rate: 6.2500e-04
# Epoch 43/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5138 - loss: 1.3567 - val_accuracy: 0.5185 - val_loss: 1.3551 - learning_rate: 6.2500e-04
# Epoch 44/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5142 - loss: 1.3534 - val_accuracy: 0.5176 - val_loss: 1.3615 - learning_rate: 6.2500e-04
# Epoch 45/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5190 - loss: 1.3516 - val_accuracy: 0.5224 - val_loss: 1.3463 - learning_rate: 3.1250e-04
# Epoch 46/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5193 - loss: 1.3445 - val_accuracy: 0.5215 - val_loss: 1.3498 - learning_rate: 3.1250e-04
# Epoch 47/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5196 - loss: 1.3437 - val_accuracy: 0.5245 - val_loss: 1.3442 - learning_rate: 3.1250e-04
# Epoch 48/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5182 - loss: 1.3431 - val_accuracy: 0.5231 - val_loss: 1.3455 - learning_rate: 3.1250e-04
# Epoch 49/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5183 - loss: 1.3451 - val_accuracy: 0.5252 - val_loss: 1.3421 - learning_rate: 3.1250e-04
# Epoch 50/50
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 33ms/step - accuracy: 0.5204 - loss: 1.3402 - val_accuracy: 0.5216 - val_loss: 1.3463 - learning_rate: 3.1250e-04

# %%
test_loss, test_acc = fcnn_cifar10.evaluate(x_test_cifar, y_test_cifar_cat, verbose=0)
print(f"FCNN test Accuracy for CIFAR-10: {test_acc:.4f}")
# Out:
# FCNN test Accuracy for CIFAR-10: 0.5249

# %%
plt.plot(history_fcnn_cifar.history['accuracy'], label='Train Accuracy')
plt.plot(history_fcnn_cifar.history['val_accuracy'], label='Validation Accuracy')
plt.title('FCNN - CIFAR-10')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
cnn1_cifar = Sequential([
    Conv2D(32, (5, 5), strides=1, padding='valid', activation='relu',
           kernel_regularizer=regularizers.l2(0.001),
           input_shape=(32, 32, 3)),
    BatchNormalization(),

    MaxPooling2D(pool_size=(2, 2), strides=2),

    Flatten(),
    Dense(100, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.5),

    Dense(10, activation='softmax')
])
cnn1_cifar.compile(
    optimizer=Adam(learning_rate=0.0008),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
early_stop = EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)
history_cnn1_cifar = cnn1_cifar.fit(
    x_train_cifar, y_train_cifar_cat,
    epochs=50,
    validation_split=0.2,
    batch_size=64,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 34ms/step - accuracy: 0.3271 - loss: 2.1217 - val_accuracy: 0.5050 - val_loss: 1.6079
# Epoch 2/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.4832 - loss: 1.6181 - val_accuracy: 0.5008 - val_loss: 1.6108
# Epoch 3/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.5362 - loss: 1.4766 - val_accuracy: 0.4873 - val_loss: 1.7839
# Epoch 4/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.5638 - loss: 1.4281 - val_accuracy: 0.5919 - val_loss: 1.3783
# Epoch 5/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.5838 - loss: 1.3724 - val_accuracy: 0.5990 - val_loss: 1.3999
# Epoch 6/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.6056 - loss: 1.3429 - val_accuracy: 0.6116 - val_loss: 1.3654
# Epoch 7/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.6171 - loss: 1.3200 - val_accuracy: 0.6251 - val_loss: 1.3405
# Epoch 8/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 33ms/step - accuracy: 0.6260 - loss: 1.3073 - val_accuracy: 0.6197 - val_loss: 1.3524
# Epoch 9/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.6336 - loss: 1.2909 - val_accuracy: 0.6327 - val_loss: 1.3226
# Epoch 10/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.6425 - loss: 1.2735 - val_accuracy: 0.6331 - val_loss: 1.3286
# Epoch 11/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 20s 32ms/step - accuracy: 0.6537 - loss: 1.2527 - val_accuracy: 0.6257 - val_loss: 1.3454
# Epoch 12/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 33ms/step - accuracy: 0.6593 - loss: 1.2475 - val_accuracy: 0.5470 - val_loss: 1.7050
# Epoch 13/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.6556 - loss: 1.2589 - val_accuracy: 0.6459 - val_loss: 1.3289
# Epoch 14/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 21s 34ms/step - accuracy: 0.6691 - loss: 1.2444 - val_accuracy: 0.6178 - val_loss: 1.4262
# Epoch 15/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - accuracy: 0.6658 - loss: 1.2462 - val_accuracy: 0.6317 - val_loss: 1.4127

# %%
test_loss, test_acc = cnn1_cifar.evaluate(x_test_cifar, y_test_cifar_cat, verbose=0)
print(f"CNN1 test Accuracy for CIFAR-10: {test_acc:.4f}")
# Out:
# CNN1 test Accuracy for CIFAR-10: 0.6349

# %%
plt.plot(history_cnn1_cifar.history['accuracy'], label='Train Accuracy')
plt.plot(history_cnn1_cifar.history['val_accuracy'], label='Validation Accuracy')
plt.title('FCNN - CIFAR-10')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()

# %%
cnn2_cifar = Sequential([
    Conv2D(32, (3, 3), strides=1, padding='same', activation='relu',
           kernel_regularizer=regularizers.l2(0.001),
           input_shape=(32, 32, 3)),
    BatchNormalization(),
    Conv2D(32, (3, 3), strides=1, padding='same', activation='relu',
           kernel_regularizer=regularizers.l2(0.001)),
    BatchNormalization(),
    MaxPooling2D(pool_size=(2, 2), strides=2),
    Flatten(),
    Dense(100, activation='relu', kernel_regularizer=regularizers.l2(0.001)),
    Dropout(0.3),

    Dense(10, activation='softmax')
])
cnn2_cifar.compile(
    optimizer=Adam(learning_rate=0.0008),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

early_stop = EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True)
history_cnn2_cifar = cnn2_cifar.fit(
    x_train_cifar, y_train_cifar_cat,
    epochs=50,
    validation_split=0.2,
    batch_size=64,
    callbacks=[early_stop],
    verbose=1
)
# Out:
# Epoch 1/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 74s 114ms/step - accuracy: 0.3329 - loss: 2.1431 - val_accuracy: 0.5398 - val_loss: 1.4951
# Epoch 2/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 76s 122ms/step - accuracy: 0.5256 - loss: 1.5166 - val_accuracy: 0.6056 - val_loss: 1.3046
# Epoch 3/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 75s 121ms/step - accuracy: 0.5941 - loss: 1.3263 - val_accuracy: 0.6333 - val_loss: 1.2764
# Epoch 4/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 67s 107ms/step - accuracy: 0.6404 - loss: 1.2353 - val_accuracy: 0.6191 - val_loss: 1.3506
# Epoch 5/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 57s 91ms/step - accuracy: 0.6662 - loss: 1.2090 - val_accuracy: 0.6457 - val_loss: 1.3168
# Epoch 6/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 57s 91ms/step - accuracy: 0.6930 - loss: 1.1681 - val_accuracy: 0.6446 - val_loss: 1.3572
# Epoch 7/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 57s 90ms/step - accuracy: 0.7123 - loss: 1.1493 - val_accuracy: 0.6601 - val_loss: 1.3821
# Epoch 8/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 56s 89ms/step - accuracy: 0.7386 - loss: 1.1094 - val_accuracy: 0.6318 - val_loss: 1.5249
# Epoch 9/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 56s 90ms/step - accuracy: 0.7495 - loss: 1.1028 - val_accuracy: 0.6696 - val_loss: 1.4330
# Epoch 10/50
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 58s 93ms/step - accuracy: 0.7749 - loss: 1.0651 - val_accuracy: 0.6495 - val_loss: 1.6106

# %%
test_loss, test_acc = cnn2_cifar.evaluate(x_test_cifar, y_test_cifar_cat, verbose=0)
print(f"CNN2 test Accuracy for CIFAR-10: {test_acc:.4f}")
# Out:
# CNN2 test Accuracy for CIFAR-10: 0.6313

# %%
plt.plot(history_cnn2_cifar.history['accuracy'], label='Train Accuracy')
plt.plot(history_cnn2_cifar.history['val_accuracy'], label='Validation Accuracy')
plt.title('FCNN - CIFAR-10')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
